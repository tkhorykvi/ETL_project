# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "amazon_products.csv"
amazon_data_df = pd.read_csv(csv_file)
cleaned_df = amazon_data_df.drop(columns=['price', 'originalPrice', 'reviewUrl'])
cleaned_df = cleaned_df.loc[(cleaned_df['totalReviews'] >= 50) & (cleaned_df['rating'] >= 3.0)]
cleaned_df
# Out:
#            asin     brand                                              title  \
# 9    B002WTC1NG  Motorola     Motorola Barrage V860 Phone (Verizon Wireless)
# 10   B0033SFV5A   Samsung  Verizon or PagePlus Samsung Smooth U350 Great ...
# 12   B003P2VNAQ   Samsung                     Samsung Rugby II, Black (AT&T)
# 16   B004C7NVD0   Samsung  Samsung Convoy SCH-U640 Cell Phone Ruggedized ...
# 17   B004GLQTG8   Samsung                     Samsung R355C Net 10 Unlimited
# ..          ...       ...                                                ...
# 695  B07YMNLXL3    Google      Google Pixel 4 - Just Black - 64GB - Unlocked
# 697  B07YQ58NPF    Xiaomi  Xiaomi Redmi Note 8 Pro 128GB, 6GB RAM 6.53" L...
# 701  B07YZLRS3Z    Xiaomi  Xiaomi Redmi Note 8 64GB + 4GB RAM, 6.3" LTE 4...
# 708  B07ZDJCL76   Samsung  Samsung Galaxy A20s A207/DS, 32GB/3GB RAM Dual...
# 717  B081H6STQQ      Sony  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
#
#                                                    url  \
# 9    https://www.amazon.com/Motorola-Barrage-V860-V...
# 10   https://www.amazon.com/Verizon-PagePlus-Samsun...
# 12   https://www.amazon.com/Samsung-Rugby-II-Black-...
# 16   https://www.amazon.com/Samsung-SCH-U640-Rugged...
# 17   https://www.amazon.com/Samsung-R355C-Net-10-Un...
# ..                                                 ...
# 695  https://www.amazon.com/Google-Pixel-Just-Black...
# 697  https://www.amazon.com/Xiaomi-Redmi-Note-128GB...
# 701  https://www.amazon.com/Xiaomi-Redmi-Factory-Un...
# 708  https://www.amazon.com/Samsung-Snapdragon-Fact...
# 717  https://www.amazon.com/Sony-Smartphone-WH1000X...
#
#                                                  image  rating  totalReviews
# 9    https://m.media-amazon.com/images/I/81k6Nq0KI1...     3.6           352
# 10   https://m.media-amazon.com/images/I/61nD-TYqHm...     3.3            57
# 12   https://m.media-amazon.com/images/I/81RAS6NJR5...     3.6            70
# 16   https://m.media-amazon.com/images/I/61ve0RjDSU...     3.2           107
# 17   https://m.media-amazon.com/images/I/51p8LMQ-rI...     3.5           146
# ..                                                 ...     ...           ...
# 695  https://m.media-amazon.com/images/I/61C9GrXEp4...     4.2           241
# 697  https://m.media-amazon.com/images/I/71Wdzni6wR...     4.6           127
# 701  https://m.media-amazon.com/images/I/61YjtJEsM2...     4.6           103
# 708  https://m.media-amazon.com/images/I/51y15-dg6f...     4.4            52
# 717  https://m.media-amazon.com/images/I/51zZTAXZTP...     4.5            70
#
# [296 rows x 7 columns]

# %%
csv_file1 = "amazon_reviews.csv"
amazon_reviews_data = pd.read_csv(csv_file1)
amazon_reviews_data
# Out:
#              asin               name  rating                date  verified  \
# 0      B0000SX2UC              Janet       3    October 11, 2005     False
# 1      B0000SX2UC         Luke Wyatt       1     January 7, 2004     False
# 2      B0000SX2UC             Brooke       5   December 30, 2003     False
# 3      B0000SX2UC      amy m. teague       3      March 18, 2004     False
# 4      B0000SX2UC      tristazbimmer       4     August 28, 2005     False
# ...           ...                ...     ...                 ...       ...
# 67981  B081H6STQQ              jande       5     August 16, 2019     False
# 67982  B081H6STQQ            2cool4u       5  September 14, 2019     False
# 67983  B081H6STQQ              simon       5       July 14, 2019     False
# 67984  B081TJFVCJ  Tobiasz Jedrysiak       5   December 24, 2019      True
# 67985  B0825BB7SG      Owen Gonzalez       5   December 11, 2019     False
#
#                                                    title  \
# 0                            Def not best, but not worst
# 1                            Text Messaging Doesn't Work
# 2                                        Love This Phone
# 3                                Love the Phone, BUT...!
# 4           Great phone service and options, lousy case!
# ...                                                  ...
# 67981  Awesome Phone, but finger scanner is a big mis...
# 67982                                    Simply Amazing!
# 67983  great phon3, but many bugs need to fix. still ...
# 67984                                  Phone is like new
# 67985                    Outstanding phone for the price
#
#                                                     body  helpfulVotes
# 0      I had the Samsung A600 for awhile which is abs...           1.0
# 1      Due to a software issue between Nokia and Spri...          17.0
# 2      This is a great, reliable phone. I also purcha...           5.0
# 3      I love the phone and all, because I really did...           1.0
# 4      The phone has been great for every purpose it ...           1.0
# ...                                                  ...           ...
# 67981  I love the camera on this phone. The screen is...           1.0
# 67982  I've been an Xperia user for several years and...           1.0
# 67983                         buy one more for my cousin           NaN
# 67984  Product looks and works like new. Very much re...           NaN
# 67985  I love the size and style of this phone. It is...           NaN
#
# [67986 rows x 8 columns]
